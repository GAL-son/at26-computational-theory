# %% [markdown]
# ### Excercises from 3.1 - 3.8
#
# Those excercises will work on the data from `dogs_1.csv`
#
# Loading data bellow

# %%
import pandas as pd

df = pd.read_csv('data/dogs_1.csv', delimiter=',')
print(df)

# %% [markdown]
# ### 3.1
#
# Lising most important information system features

# %%
from src.information_system import InformationSystem

system = InformationSystem(df, 'Rasa')

print(f"U: {system.get_universe()}")
for i, attribute in enumerate(system.get_attributes()):
    print(f"Q{i}: {attribute}")
